# %% [markdown]
# address coding

# %%
import pandas as pd
import requests
import time
from typing import List, Dict, Any, Optional, Tuple
import pandas as pd

def geocode_address(address: str) -> Tuple[Optional[Dict[str, Any]], Optional[str]]:
    """
    Geocode an address using Nominatim and return specific metadata.
    
    Args:
    address (str): The address string to geocode.
    
    Returns:
    Tuple[Optional[Dict[str, Any]], Optional[str]]: A tuple containing the processed result (or None) and an error message (or None).
    """
    base_url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": address,
        "format": "json",
        "limit": 1,
        "addressdetails": 1,
        "extratags": 1,
    }
    
    try:
        response = requests.get(base_url, params=params, headers={"User-Agent": "YourAppName"})
        response.raise_for_status()  # Raise an exception for bad status codes
        data = response.json()
    except requests.RequestException as e:
        return None, f"Error occurred while fetching data: {str(e)}"
    
    if data and isinstance(data, list) and len(data) > 0:
        result = data[0]
        extratags = result.get('extratags') or {}
        address_details = result.get('address') or {}
        processed_result = {
            "Search_Address": address,
            "OSM_ID": f"{result.get('osm_type', 'way')} {result.get('osm_id')}",
            "Name": result.get('name', 'No Name'),
            "Type": f"{result.get('type', 'Unknown')}:{result.get('class', 'Unknown')}",
            "Last_Updated": result.get('timestamp', 'Unknown'),
            "Search_Rank": result.get('place_rank', 'Unknown'),
            "Address_Rank": f"{result.get('place_rank', 'Unknown')} ({result.get('type', 'Unknown')})",
            "Importance": result.get('importance', 0),
            "Coverage": "Polygon" if 'polygon' in result else 'Point',
            "Latitude": result.get('lat', 'Unknown'),
            "Longitude": result.get('lon', 'Unknown'),
            "Height": extratags.get('height', 'Unknown'),
            "Place_Id": result.get('place_id', 'Unknown'),
            "City": address_details.get('city') or address_details.get('town') or address_details.get('village', 'Unknown'),
            "Street": address_details.get('road', 'Unknown'),
            "Postcode": address_details.get('postcode', 'Unknown'),
            "Housenumber": address_details.get('house_number', 'Unknown'),
            "Extra_Tags": ", ".join([f"{k} ({v})" for k, v in extratags.items() if k != 'height'])
        }
        return processed_result, None
    else:
        return None, "No data found for this address"

def geocode_addresses(addresses: List[str]) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Geocode a list of addresses using Nominatim and return two DataFrames:
    one with successful results and another with failed addresses.
    
    Args:
    addresses (List[str]): A list of address strings to geocode.
    
    Returns:
    Tuple[pd.DataFrame, pd.DataFrame]: A tuple containing two DataFrames:
        1. DataFrame with successful geocoding results
        2. DataFrame with failed addresses and error messages
    """
    successful_results = []
    failed_results = []

    for address in addresses:
        result, error_message = geocode_address(address)
        if result:
            successful_results.append(result)
        else:
            failed_results.append({"Search_Address": address, "Error": error_message})
        
        # Be nice to the Nominatim server by waiting between requests
        time.sleep(1)

    return pd.DataFrame(successful_results), pd.DataFrame(failed_results)

# %%
addresses = pd.read_csv(r"C:\Users\Jerem\OneDrive\Desktop\hackathon\addresses.csv")
addresses = addresses['Full Address'].to_list()
addresses = addresses
addresses
# Out:
# ['58-01 Grand Avenue, Queens NY 11378',
#  '1870 Pelham Parkway South, Bronx NY 10461',
#  '2011 Mott Ave, Far Rockaway NY 11691',
#  '215 East 99th Street, New York NY 10029',
#  '23-25 31 Street, Queens NY 11105',
#  '1680 Ocean Ave, Brooklyn NY 11230',
#  '33-70 Prince Street, Queens NY 11354',
#  '2021 Pitkin Avenue, Brooklyn NY 11207',
#  '88-24 Merrick Blvd, Jamaica NY 11432',
#  '90-11 149 str, Jamaica NY 11435',
#  '148-25 89 Ave, Jamaica NY 11435',
#  '166-05 89 Ave, Jamaica NY 11432',
#  '403 Hewes Street, Brooklyn NY 11211',
#  '409 Hewes Street, Brooklyn NY 11211',
#  '1882 Grand Concourse, Bronx NY 10457',
#  '990 Aldus Street, Bronx NY 10459',
#  '996 Aldus Street, Bronx NY 10459',
#  '1025 Aldus Street, Bronx NY 10459',
#  '1032 Aldus Street, Bronx NY 10459',
#  '1010 Bryant Avenue, Bronx NY 10459',
#  '1016 Bryant Avenue, Bronx NY 10459',
#  '57-67 West 175 Street, Bronx NY 10453',
#  '1664 Macombs Road, Bronx NY 10453',
#  '1674 MAcombs Road, Bronx NY 10453',
#  '1325 Grand Concourse, Bronx NY 10452',
#  '115 Marcy Place, Bronx NY 10452',
#  '133 Clarke Place East, Bronx NY 10452',
#  '1200 Union Ave/1204 Union Ave, Bronx NY 10459',
#  '1215 Union Ave, Bronx NY 10456',
#  '135 Hamilton Place, New York NY 10031',
#  '500 West 144th street/144 Hamilton Place, New York NY 10031',
#  '596 Riverside Drive, New York NY 10031',
#  '89-02 165 St, Queens NY 11432',
#  '367 S 2nd St, Brooklyn NY 11211',
#  '33-01 Vernon Blvd, Queens NY 11106',
#  '2070 Adam Clayton Powell Jr. Blvd, Manhattan NY 10027',
#  '225 West 123rd St, Manhattan NY 10027',
#  '475 W. 250 St., Bronx NY 10471',
#  '120 3rd St, Brooklyn NY 11231',
#  '26-32 Skillman Avenue, Queens NY 11101',
#  '973 Brook Avenue, Bronx NY 10451',
#  '115-10 14 Road, Queens NY 11356',
#  '21-24 44 Avenue, Queens NY 11101',
#  '38-19 Union Street, Queens NY 11354',
#  '9 East 4th Street, New York NY 10003',
#  '43-53 Main Street, Queens NY 11355',
#  '97 Columbia Heights, Brooklyn NY 11201',
#  '218-01 Merrick Blvd, Queens NY 11413',
#  '334 East 79 St, New York NY 10075',
#  '1404 Ocean Parkway, Brooklyn NY 11230',
#  '2442 Ocean Avenue, Brooklyn NY 11229',
#  '111-28 37 Avenue, Queens NY 11368',
#  '154 North 7 Street, Brooklyn NY 11249',
#  '1517 Bushwick Avenue, Brooklyn NY 11207',
#  '60-01 Roosevelt Avenue, Queens NY 11377',
#  '40-05 59 St, Queens NY 11377',
#  '188-192 6 Avenue, New York NY 10013',
#  '188 6 Avenue, New York NY 10013',
#  '190 6 Ave, New York NY 10013',
#  '192 6 Ave, New York NY 10013',
#  '9 East 4th St, New York NY 10003',
#  '9 East 4th St, New York NY 10003',
#  '392 Lafayette St, New York NY 10003',
#  '110 East 153 St, Bronx NY 10451',
#  '15 West 44th Street, New York NY 10036',
#  '312 West 37 Street, Manhattan NY 10018',
#  '2900 East 29 Street, Brooklyn NY 11235',
#  '2800 East 29 Street, Brooklyn NY 11235',
#  '2900 East 29 Street, Brooklyn NY 11235',
#  '2812 Kings Highway, Brooklyn NY 11222',
#  '403 Broome Street, New York NY 10013',
#  '241 Centre Street, New York NY 10013',
#  '409 Broome St, New York NY 10013',
#  '179 Lafayette Street, New York NY 10013',
#  '239 Centre Street, New York NY 10013',
#  '237 Centre Street, New York NY 10013',
#  '407 Broome Street, New York NY 10013',
#  '302 Sheffield Ave., Brooklyn NY 11207',
#  '253 Centre St, New York NY 10013',
#  '407 Broome Street, New York NY 10013',
#  '2321 Belmont Avenue, Bronx NY 10458',
#  '32-65 107 Street, Queens NY 11369',
#  '42-01 35 Street, Queens NY 11101',
#  '11 West 37 Street, New York NY 10018',
#  '60 Monitor Street, Brooklyn NY 11222',
#  '62-41 Forest Ave, Queens NY 11385',
#  '18-81 Steinway Street, Queens NY 11105',
#  '329 9th Street, Brooklyn NY 11215',
#  '901-949 E 107th Street, Brooklyn NY 11236',
#  '2236 Nostrand Avenue, Brooklyn NY 11210',
#  '1960 Benedict Avenue, Bronx NY 10462',
#  '1952 Benedict Avenue, Bronx NY 10462',
#  '1001-1011 Brighton Beach Avenue, Brooklyn NY 11235',
#  '144-38 35 Avenue, Queens NY 11354',
#  '802 Avenue U, Brooklyn NY 11223',
#  '340 Johnson Avenue, Brooklyn NY 11206',
#  '2294-96 Grand Ave, Bronx NY 10468',
#  '415 East 204th Street, Bronx NY 10467',
#  '2503 Ocean Avenue, Brooklyn NY 11229',
#  '39-82 65 Place, Queens NY 11377',
#  '5213-5221 Flatlands Ave, Brooklyn NY 11234',
#  '1166 Manhattan Ave, Brooklyn NY 11222',
#  '207 Starr St, Brooklyn NY 11237',
#  '278 West 10 Street, New York NY 10014',
#  '123 West 43 Street, New York NY 10036',
#  '106 West 117 St, New York NY 10026',
#  '1164 Manhattan Ave - Child, Brooklyn NY 11222',
#  '1166 Manhattan Ave, Brooklyn NY 11222',
#  '556 West 22 Street, New York NY 10011',
#  '602 West 139th St, New York NY 10031',
#  '884 Riverside Drive, New York NY 10032',
#  '575 West 159th St, New York NY 10032',
#  '3456 Broadway, New York NY 10031',
#  '500 West 140th St, New York NY 10031',
#  '461 W 159 St, New York NY 10032',
#  '3750 Broadway, New York NY 10032',
#  '559 W 156 st, New York NY 10032',
#  '605 West 141 St, New York NY 10031',
#  '2363 ACP Boulevard, New York NY 10030',
#  '3427 Broadway, New York NY 10031',
#  '580 St. Nicholas Ave, New York NY 10030',
#  '3660 Broadway, New York NY 10031',
#  '605 West 151 St, New York NY 10031',
#  '2345 University Ave, Bronx NY 10468',
#  '720 Fifth Avenue, New York NY 10019',
#  '724 5th Avenue, New York NY 10019',
#  '200 Boscombe Avenue, Staten Island NY 10309',
#  '300 west 12th street, New York NY 10014',
#  '82 Washington place, New York NY 10011',
#  '363 West 16th Street, New York NY 10011',
#  '120 W 57th Street, New York NY 10019',
#  '1730 Ocean Ave, New York NY 11230',
#  '2278 Bronx Park East, Bronx NY 10467',
#  '120 3rd Street, Brooklyn NY 11231',
#  '110 3rd Street, Brooklyn NY 11231',
#  '370 4 Avenue, Brooklyn NY 11215',
#  '860 Pennsylvania Ave, Brooklyn NY 11207',
#  '3440 Broadway, New Yor NY 10031',
#  '720 West End Ave, New York NY 10025',
#  '1631 Grand Ave, Bronx NY 10453',
#  '226 W Tremont Ave, Bronx NY 10453',
#  '1786 Topping Ave, Bronx NY 10457',
#  '224 West 30th Street, New York NY 10001',
#  '247 East 28th Street, New York NY 10016',
#  '1100 Coney Island Avenue, Brooklyn NY 11230',
#  '1122 Coney Island Avenue, Brooklyn NY 11230',
#  '49-07 1 Ave, Brooklyn NY 11232',
#  '53-01 1St Ave, Brooklyn NY 11220',
#  '140 53 St, Brooklyn NY 11232',
#  '569 Lexington Ave, New York NY 10022',
#  '3700 3rd Ave, Bronx NY 10456',
#  '311 West 34th Street, New York NY 10001',
#  '2265 Gerritsen Ave, Brooklyn NY 11229',
#  '83-37 St. James Avenue, Queens NY 11373',
#  '122 57 Street, Brooklyn NY 11220',
#  '2245 Barker Ave, Bronx NY 10467',
#  '2255 Barker Avenue, Bronx NY 10467',
#  '637 E 176 St, Bronx NY 10457',
#  '1543 East 19th Street, Brooklyn NY 11230',
#  '37 Greenpoint Ave/102 West St, Brooklyn NY 11222',
#  '145 Henry Street, Brooklyn NY 11201',
#  '227 East 59th St, New York NY 10022',
#  '37 Greenpoint Ave, Brooklyn NY 11222',
#  '102 West St, Brooklyn NY 11222',
#  '70 Ross Street, Brooklyn NY 11249',
#  '70 Ross Street, Brooklyn NY 11249',
#  '94 Ross Street, Brooklyn NY 11249',
#  '104 Ross Street, Brooklyn NY 11249',
#  '74 Ross Street, Brooklyn NY 11249',
#  '80 Ross Street, Brooklyn NY 11249',
#  '84 Ross Street, Brooklyn NY 11249',
#  '90 Ross Street, Brooklyn NY 11249',
#  '100 Ross Street, Brooklyn NY 11249',
#  '200-210 East 165 Street (204), Bronx NY 10456',
#  '212-222 East 165 Street (218), Bronx NY 10456',
#  '200-222 East 165 Street, Bronx NY 10456',
#  '43-46 51st St, Queens NY 11377',
#  '170 Van Brunt Street, Brooklyn NY 11231',
#  '69 2nd Avenue, Brooklyn NY 11215',
#  '1455 Grand Concourse, Bronx NY 10452',
#  '1587 E 19th Street, Brooklyn NY 11230',
#  '456 Hudson St, New York NY 10014',
#  '456 Hudson St, New York NY 10014',
#  '83-85 Barrow Street, New Yoirk NY 10014',
#  '63 Morton Street, New York NY 10014',
#  '67 Morton Street, New York NY 10014',
#  '136-140 West 23rd St, New York NY 10011',
#  '2345 60th Street, Brooklyn NY 11204',
#  '8701 4 Avenue, Brooklyn NY 11209',
#  '132 West 116 Street, New York NY 10026',
#  '2050 Second Ave, New York NY 10029',
#  '1240 Edward L Grant Highway, Bronx NY 10452',
#  '647 West 174 Street, New York NY 10033',
#  '2537 Broadway, New York NY 10025',
#  '40-36 27 Street, Queens NY 11101',
#  '87-24 162nd Street, Queens NY 11432',
#  '160-20 Highland Avenue, Queens NY 11432',
#  '87-24 162nd Street, Queens NY 11432',
#  '57-54 Page Place, Maspeth NY 11378',
#  '127-92 Willets Point Boulevard, Corona NY 11368',
#  '127-92 Garage Willets Point Boulevard, Corona NY 11368',
#  '129-02 Northern Blvd, Corona NY 11368',
#  '127-90 Willets Point Boulevard, Corona NY 11368',
#  '57 Herkimer Street, Brooklyn NY 11216',
#  '236 17th Street, Brooklyn NY 11215',
#  '1329 Willoughby Avenue, Brooklyn NY 11237',
#  '45 Bowne Street, Brooklyn NY 11231',
#  '48 Great Jones Street, New York NY 10012',
#  '338 West 39 St, New York NY 10018',
#  '23 East 39 St, New York NY 10016',
#  '760 Parkside Avenue, Brooklyn NY 11226',
#  '90 Varick Avenue, Brooklyn NY 11237',
#  '109-15 72 Road, Queens NY 11375',
#  '134-140 Grand St, New York NY 10013',
#  '417 Lafayette St, New York NY 10003',
#  '31-72 31st Street, Queens NY 11106',
#  '31-64 21st Street, Queens NY 11106',
#  '2911 86 Street, Brooklyn NY 11223',
#  '818 Lexington Ave, Brooklyn NY 11221',
#  '186 East 205 Street, Bronx NY 10458',
#  '144-69 Barclay Ave, Queens NY 11355',
#  '2820 Middle Town Road, Bronx NY 10461',
#  '863 E 141st St, Bronx NY 10454',
#  '327 Walnut Avenue, Bronx NY 10454',
#  '23-23 Borden Avenue, Queens NY 11101',
#  '607 West 47 Street, New York NY 10036',
#  '428 E 92 Street, New York NY 10128',
#  '147-25 Northern Blvd, Queens NY 11354',
#  '46-01 67 Street, Queens NY 11377',
#  '112-22 37 Ave, Queens NY 11368',
#  '15 W 39 Street, New York NY 10018',
#  '3120 Corlear Avenue, Bronx NY 10463',
#  '57 Willoughby Street, Brooklyn NY 11201',
#  '150 East 45th Street, New York NY 10017',
#  '37 West 39th Street, New York NY 10018',
#  '242 West 38th Street, New York NY 10018',
#  '347 West 36th Street, New York NY 10018',
#  '251 West 30th Street, New York NY 10001',
#  '16 West 36th Street, New York NY 10018',
#  '229 West 28th Street, New York NY 10001',
#  '24-32 Union Square, New York NY 10003',
#  '8-18 Queens Plaza South, Queens NY 11101',
#  '42-11 Vernon Boulevard, Queens NY 11101',
#  '42-22 9 Street, Queens NY 11101',
#  '8-18 Queens Plaza South, Queens NY 11102',
#  '89-31 161 Street, Queens NY 11432',
#  '2021 Amsterdam Avenue, New York NY 10032',
#  '1964 Grand Concourse, Bronx NY 10457',
#  '5-7 Mercer St, Manhattan NY 10013',
#  '165 Eldridge Street, New York NY 10002',
#  '195 Bowery St, Manhattan NY 10002',
#  '200 East 11 Street, Manhattan NY 10003',
#  '43 Bleecker Street, Manhattan NY 10012',
#  '517 West 29th Street, New York NY 10001',
#  '131 West 35th Street, New York NY 10001',
#  '16 West 39th Street, Manhattan NY 10018',
#  '237 Madison Avenue, New York NY 10016',
#  '135 East 50th Street, Manhattan NY 10022',
#  '350 East 52nd Street, Manhattan NY 10022',
#  '809 Madison Ave, Manhattan NY 10065',
#  '350 West 110th Street, New York NY 10025',
#  '415 West 150th Street, Manhattan NY 10031',
#  '779 Riverside Drive, Manhattan NY 10032',
#  '13-19 Cumming Street, New York NY 10034',
#  '1776 Castle Hill Ave, Bronx NY 10462',
#  '3750 Bronx Blvd, Bronx NY 10467',
#  '945 Bergen Street, Brooklyn NY 11216',
#  '770 St Marks Avenue, Brooklyn NY 11216',
#  '151 Kent Avenue, Brooklyn NY 11249',
#  '5-11 Hope St, Brooklyn NY 11211',
#  '13-19 Hope Street, Brooklyn NY 11211',
#  '1-3 Hope St/153-155 Roebling St, Brooklyn NY 11211',
#  '314 Metropolitan/143-145 Roebling Street, Brooklyn NY 11211',
#  '143 Roebling Street, Brooklyn NY 11211',
#  '50 North 1st Street, Brooklyn NY 11249',
#  '68 Richardson St, Brooklyn NY 11211',
#  '992 Amsterdam Ave, New York NY 10025',
#  '587 Riverside Drive, New York NY 10031',
#  '900 Riverside Drive, New York NY 10032',
#  '5 Delavan Street, Brooklyn NY 11231',
#  '450 Ninth Avenue, New York NY 10018',
#  '13-25 Eggert Place, Queens NY 11691',
#  '13-25 Eggert Place, Queens NY 11691',
#  '13-18/13-32 Dickens Street, Queens NY 11691',
#  '23-40 Mott Avenue, Queens NY 11691',
#  '22-30 Mott Avenue, Queens NY 11691',
#  '37-68 97th Street, Queens NY 11368',
#  '168-42 88th Avenue, Queens NY 11432',
#  '88-44 161st Street, Queens NY 11432',
#  '168-36 88th Avenue, Queens NY 11432',
#  '42-37 Hampton Street, Queens NY 11373',
#  '88-35 Elmhurst Avenue, Queens NY 11373',
#  '42-25 Hampton Street, Queens NY 11373',
#  '215 Varick Avenue, Brooklyn NY 11237',
#  '485 Scott Avenue, Brooklyn NY 11222',
#  '30-47 29th Street, Queens NY 11102',
#  '119 Columbia Heights, Brooklyn NY 11201',
#  '148 East 33 Street, New York NY 10001',
#  '525 Lexington Ave, New York NY 10017',
#  '218-01 Merrick Blvd, Queens NY 11413',
#  '451 Clinton Ave, Brooklyn NY 11238',
#  '5-11 Windham Loop, Staten Island NY 10314',
#  '133-51 39 Avenue, Queens NY 11354',
#  '330 West 42nd Street, New York NY 10036',
#  '413 East 137 Street, Bronx NY 10454',
#  '475 East 138 St, Bronx NY 10454',
#  '228 West 147th Street, New York NY 10039',
#  '465 West 152nd Street, New York NY 10031',
#  '4925 Broadway, New York NY 10034',
#  '549 Isham Street, New York NY 10034',
#  '573 Isham Street, New York NY 10034',
#  '998 Amsterdam Ave, New York NY 10025',
#  '992-998 Amsterdam Ave, New York NY 10025',
#  '37-19 32nd Street, Queens NY 11101',
#  '440 West 21 Street, New York NY 10011',
#  '175 9th Ave, New York NY 10011',
#  '440 West 21 Street, New York NY 10011',
#  '2733 E 12 Street, Brooklyn NY 11235',
#  '49 CLARKSON AVENUE, Brooklyn NY 11226',
#  '5609 15th Ave, Brooklyn NY 11219',
#  '740 EMPIRE BLVD, Brooklyn NY 11213',
#  '8904 148TH STREET, Queens NY 11435',
#  '1045 St Johns Pl, Brooklyn NY 11213',
#  '277 ROCKAWAY PKWY, Brooklyn NY 11212',
#  '280 CROWN ST, Brooklyn NY 11225',
#  '91-32/34 195th Street, Queens NY 11423',
#  '947 MONTGOMERY ST, Brooklyn NY 11213',
#  '1004 Montgomery Street, Brooklyn NY 11213',
#  '1010 LINCOLN PLACE, Brooklyn NY 11213',
#  '1245 EASTERN PARKWAY, Brooklyn NY 11213',
#  '332 ROGERS AVE, Brooklyn NY 11225',
#  '320 EMPIRE BLVD, Brooklyn NY 11225',
#  '930 Flushing Ave, Brooklyn NY 11206',
#  '1760 Union St, Brooklyn NY 11213',
#  '1777 Ocean Pkwy, Brooklyn NY 11223',
#  '57 Lincoln Rd, Brooklyn NY 11225',
#  '9302 Kings Hwy, Brooklyn NY 11212',
#  '40 WOODRUFF AVE, Brooklyn NY 11226',
#  '961 EASTERN PKWY, Brooklyn NY 11213',
#  '300 LINDEN BLVD, Brooklyn NY 11226',
#  '325 E176th Street, Bronx NY 10457',
#  '363 New York Ave, Brooklyn NY 11213',
#  '37 Payson Ave., New York NY 10034',
#  '181 CLARKSON AVE, Brooklyn NY 11226',
#  '4420 15th Ave., Brooklyn NY 11219',
#  '2 Stoddard Place, Brooklyn NY 11225',
#  '1045 St Johns Pl, Brooklyn NY 11213',
#  '1025 St Johns Pl, Brooklyn NY 11213',
#  '545 West 148 Street, Manhattan NY 10031',
#  '515 West 111 Street, Manhattan NY 10025',
#  '175 5th Avenue, New York NY 10010',
#  '88 Beast Coast, Brooklyn NY 11229',
#  '2387 Ocean Avenue, Brooklyn NY 11229',
#  '2285 Ocean Avenue, Brooklyn NY 11229',
#  '1755 Ocean Parkway, Brooklyn NY 11223',
#  '1270 East 19th Street, Brooklyn NY 11230',
#  '1280 East 12th Street, Brooklyn NY 11230',
#  '130 Avenue P, Brooklyn NY 11204',
#  '2134 Homecrest Ave, Brooklyn NY 11229',
#  '2245 E. 19th Street, Brooklyn NY 11229',
#  '30 Dongan Pl, New York NY 10040',
#  '91 Fort Washington Avenue, New York NY 10032',
#  '4720 Broadway, New York NY 10040',
#  '1648 West 9th Street, Brooklyn NY 11223',
#  '2306 Ocean Ave, Brooklyn NY 11229',
#  '1675 West 9th St, Brooklyn NY 11223',
#  '70 Dahill Road, Brooklyn NY 11218',
#  '676 Riverside Drive, New York NY 10031',
#  '145 West 96th Street, New York NY 10025',
#  '155 West 81st Street, New York NY 10024',
#  '21 East 10th street, New York NY 10003',
#  '308 West104, New York NY 10025',
#  '740 West End Avenue, New York NY 10025',
#  '939 Eigth Avenue, New York NY 10019',
#  '801 West 190th Street, New York NY 10040',
#  '3525 Baychester Avenue, Bronx NY 10466',
#  '520 East 81st Street, New YOrk NY 10028',
#  '73-12 35 Avenue,, Queens NY 11372',
#  '64-11 99 Street,, Queens, NY 11374',
#  '10 Shore Boulevard,, Brooklyn NY 10022',
#  '40 Shore Boulevard, Brooklyn NY 11235',
#  '9101 Shore Road, Brooklyn NY 11209',
#  '164-20 Highland Avenue, Queens NY 11432',
#  '91-31 Queens Boulevard, Queens NY 11373',
#  '7901 4th Avenue, Brooklyn NY 11209',
#  '629 Kappock Street, Bronx NY 10463',
#  '155 East 91 Street, Manhattan NY 10128',
#  '41-42 66 Street, Queens NY 11377',
#  '1116 Carroll Street, Brooklyn NY 11225',
#  '3033 Brighton 13 Street, Brooklyn NY 11235',
#  '171 Meserole Street, Brooklyn NY 11206',
#  '165 Meserole Street, Brooklyn NY 11206',
#  '161 East 90 Street, Manhattan NY 10128',
#  '10 / 40 Shore Boulevard,, Brooklyn NY 10022',
#  '6200 Riverdale Avenue, Bronx NY 10471',
#  '34 Laight Street, New York NY 10013',
#  '116 W. 31th Street, New York NY 10001',
#  '148-18 134th Street, Jamaica NY 11430',
#  '108 W. 24th Street, Chelsea NY 10011',
#  '320 Pearl Street, Seaport NY 10038',
#  '39 Avenue of the Americas, Tribeca NY 10013',
#  '337 West 39th Street, New York NY 10018',
#  '343 West 39th Street, New York NY 10018',
#  '339 West 39th Street, New York NY 10018',
#  '51 Nassau St, New York NY 10038',
#  '126 Water St, New York NY 10005',
#  '132 Fourth Avenue, New York NY 10003',
#  '232 W 29th Street, Manhattan NY 10001',
#  '206 East 52nd Street, New York NY 10022',
#  '237 West 54th Street, New York NY 10019',
#  '517 Lexington Ave., New York NY 10017',
#  '310 W 40th St, New York NY 10018',
#  '112-15 Northern Boulevard, Corona NY 11368',
#  '28-66 College Point Blvd, Queens NY 11354',
#  '26 Ann St, New York NY 10038',
#  '36-03 Prince Street, Flushing NY 11354',
#  '529 Empire Boulevard, Brooklyn NY 11225',
#  '38 Avenue, New York NY 11101',
#  '55-60 58 STREET, Queens, New York, NY, USA, New York NY 11378',
#  '30-35 THOMSON AVENUE, Queens, New York, NY, USA, New York / Queens NY 11101',
#  '3110 48 AVENUE, Queens, New York, NY, USA, New York NY 11101',
#  'CHRYSTIE STREET, New York NY 10002',
#  '39 WEST 31 STREET, 10001, New York NY 10001',
#  '34 WEST 32 STREET, 10001, New York NY 10001',
#  '22 W 32ND STREET, 10001, NEW YORK NY 10001',
#  '61-56 SPRINGFIELD BLVD, 11364, New York NY 11364',
#  '39-17 MAIN STREET, 11354, New York NY 11354',
#  '12 McGuinness Boulevard South, New York NY 11222',
#  '130 EAST 78 STREET, 10075, New York NY 10075',
#  '561 Johnson Ave, New York NY 11237',
#  '135 West 18 Street, New York NY 10011',
#  '535 4 AVENUE, 11215, NEW YORK NY 11215',
#  '21 WEST 118 STREET, 10026, New York NY 10026',
#  '316 EAST 91ST STREET, 10128, New York NY 10128',
#  '91 JUNIUS STREET, 11207, New York NY 11207',
#  '555 4 AVENUE,, New York NY 11215',
#  '2760 West 22nd Street, Brooklyn NY 11224',
#  '4612 Glenwood road, Brooklyn NY 10029',
#  '141 west 144 street, New York NY 10030',
#  '430 EAST 80 STREET, New York NY 10075',
#  '1131 3 AVENUE, 10065, New York NY 10065',
#  '660 BERGEN STREET, Brooklyn NY 11238',
#  '9522 SCHENCK STREET, 11236, Brooklyn NY 11236',
#  '66 AINSLIE ST, BROOKLYN NY 11211',
#  '325 LAFAYETTE AVE, Brooklyn NY 11238',
#  '2821 Briggs Avenue, Bronx NY 10458',
#  '2471 Davidson Ave, Bronx NY 10468',
#  '1111 Ward Ave, Bronx NY 10472',
#  '2494 Morris Avenue, Bronx, NY 10468',
#  '140 w 238th Street, BRONX NY 10463',
#  '222 JOHNSON AVE, BROOKLYN NY 11206',
#  '144 East 24th Street, New York NY 10010',
#  '30 East 9th Street, New York NY 10003',
#  '3139 BROADWAY, MANHATTAN NY 10027',
#  '41-45 TIEMANN PLACE, MANHATTAN NY 10027',
#  '555 Waverly Avenue, Brooklyn NY 11238',
#  '10 Westminster Rd, Brooklyn NY 11023',
#  '150 Prospect Park West, Brooklyn NY 11215',
#  '500 Nostrand Avenue, Brooklyn NY 11216',
#  '421 West 21st Street, Manhattan NY 10011',
#  '361 East 50th Street, New York NY 10022',
#  '2053 Frederick Douglass Blvd, New York NY 10026',
#  '78 Prospect Park West, Brooklyn NY 11215',
#  '97 Grand Avenue, Brooklyn NY 11205',
#  '490 Myrtle Avenue, Brooklyn NY 11205',
#  '504 Myrtle Avenue, Brooklyn NY 11205',
#  '62-60 99th Street, Queens NY 11374',
#  '310 East 2nd Street, Manhattan NY 10009',
#  '36-14 Bud Pl, Queens NY 11354',
#  '535 Classon Avenue, Brooklyn NY 11238',
#  '145 Madison Avenue, Manhattan NY 10016',
#  '1439 Unionport Rd, Bronx NY 10462',
#  '5828 44th Avenue, Queens NY 11377',
#  '275-285 Saint Nicholas Avenue, Manhattan NY 10027',
#  '3624 BROADWAY, MANHATTAN NY 10027',
#  '480 Nostrand Avenue, Brooklyn NY 11216',
#  '2 Macon Street, Brooklyn NY 11216',
#  '154 West 70th Street, New York NY 10023',
#  '780 New York Ave, Brooklyn NY 11203',
#  '60 East 12th Street, New York NY 10003',
#  '101 East 10th Street, New York NY 10003',
#  '1060 Sheridan Ave, Bronx NY 10456',
#  '617 West 170th Street, Manhattan NY 10032',
#  '623 West 170th Street, New York NY 10032',
#  '629 West 170th St, New York NY 10032',
#  '114 East 71st St, New York NY 10021',
#  '77 Clarkson Ave, Brooklyn NY 11226',
#  '850 Metropolitan Ave, Brooklyn NY 11211',
#  '2651 Broadway, Manhattan NY 10025',
#  '825 East 141 Street, Bronx NY 10454',
#  '37-05 30th St, Queens NY 11101',
#  '285 Quincy St, Brooklyn NY 11216',
#  '419 Lafayette St, New York NY 10003',
#  '552 7th Ave, New York NY 10018',
#  '573 Emerald St, Brooklyn NY 11208',
#  '869 East 147th St, Bronx NY 10455',
#  '2519 Creston Ave, Bronx NY 10468',
#  '275 West 140th St, New York NY 10030',
#  '111 Bruckner Boulevard, Bronx NY 10454',
#  '170-10 Cedarcroft Road, Jamaica NY 11432',
#  '50 East 41st Street, New York NY 10017',
#  '47-57 48th Avenue, Queens NY 11101',
#  '43-01 22nd street, Queens NY 11101',
#  '42 7 Avenue, Manhattan NY 10011',
#  '1266 Olmstead Avenue, Bronx NY 10462',
#  '10 COLUMBUS CIRCLE, New York NY 10019',
#  '9216 7th Avenue, Brooklyn NY 11228',
#  '1661 E 19TH ST, BROOKLYN NY 11229',
#  '1990 East Gun hill road, Bronx NY 10469',
#  '237 25th Street, Brooklyn NY 11232',
#  '33 CENTRAL AVE, STATEN ISLAND NY 10301',
#  '220 east 134th Street, Bronx NY 10451',
#  '3313 Church Avenue, Brooklyn NY 11203',
#  '2201 Caton Ave, Brooklyn NY 11226',
#  '1 Metropolitan Oval, Bronx NY 10462',
#  '240 Greenwich St, New York NY 10286',
#  '99-44 62nd Ave, Queens NY 11374',
#  '2044 Webster Avenue, Bronx NY 10457',
#  '102-23 Horace Harding Expressway, Corona NY 11368',
#  '1741 Pilgrim Ave, Bronx NY 10461',
#  '100-15 Ditmars Blvd, East Elmhurst NY 11369',
#  '394 montgomery st, brooklyn NY 11225',
#  '116 Bowery, New York NY 10013',
#  '61 Chrystie Street, Queens NY 11354',
#  '1 Kent Ave, Brooklyn NY 11249',
#  '2403 Third Ave, Bronx NY 10451',
#  '1001 Stanley Ave, Brooklyn NY 11208',
#  '2244 Westchester Ave, Bronx NY 10462',
#  '1975 CRESTON AVE, Bronx NY 10453',
#  '2315 Broadway, New York NY 10024',
#  '2101 Creston Avenue, Bronx NY 10453',
#  '450 Walnut Street, Yonkers NY 10701',
#  '9917 Shore Road, Brooklyn NY 11209',
#  '25-02 Steinway Street, Astoria NY 11103',
#  '25-12 Steinway Street, Astoria NY 11103',
#  '2522 Steinway Street, Astorai NY 11103',
#  '585 Gerard Avenue, Bronx NY 10451',
#  '218 West 21st Street, New York NY 11101',
#  '312 West 15 Street, New York NY 10011',
#  '110 East 138 Street, Bronx NY 10451',
#  '124 Jackson Street, Brooklyn, New York NY 11211',
#  '133-20 Avery Avenue, Flushing NY 11355',
#  '1150 Metropolitan Ave, Brooklyn NY 11237',
#  'PO Box 320671 Bush Terminal, Brooklyn NY 11232',
#  'PO Box 320671 Bush Terminal, Brooklyn NY 11232',
#  'PO Box 320671 Bush Terminal, Brooklyn NY 11232',
#  '2077 5th Avenue, New York NY 10035',
#  '2006 Madison Avenue, New York NY 10035',
#  '1824 Madison Avenue, New York NY 10035',
#  '510 West 218 Street, New York NY 11357',
#  '1322 East 14th Street, Brooklyn NY 11230',
#  '224 Centre Street, New York NY 10013',
#  '220 Park Ave South, New York NY 10003',
#  '99 University Place, New York NY 10003',
#  '60 East 11 Street, NY NY 10003',
#  '9302 Ridge Blvd, Brooklyn NY 11220',
#  '1302 Newkirk Avenue, Brooklyn NY 11230',
#  '6309 Bay Parkway, Brooklyn NY 11204',
#  '1685 Ocean Avenue, Brooklyn NY 11230',
#  '1164 Cromwell Ave, Bronx NY 10452',
#  '103-11 68th Drive, Forest Hills NY 11375',
#  '120 Ocean Parkway, Brooklyn NY 11218',
#  '36-35 167th Street, Flushing NY 11358',
#  '112-41 72nd Road, Forest Hills NY 11375',
#  '615 West 172nd Street, New York NY 10032',
#  '83-10 118th Street, Kew Gardens NY 11415',
#  '175-05 Wexford Terrace, Jamaica NY 11432',
#  '105 Pinhurst Ave, New York NY 10033',
#  '1159 Brighton Beach Avenue, Brooklyn NY 11235',
#  '1250 Ocean Parkway, Brooklyn NY 11230',
#  '4910 17th Avenue, Brooklyn NY 11204',
#  '2786 Bainbridge Ave, Bronx NY 10458',
#  '2165 Chatterton Ave, Bronx NY 10472',
#  '3109 Brighton 7th Street, Brooklyn NY 11235',
#  '5 Minerva Place, Bronx NY 10468',
#  '1180 Ocean Parkway, Brooklyn NY 11230',
#  '1565 Thieriot Ave, Bronx NY 10460',
#  '401 East 81st Street, New York NY 10028',
#  '34-43 Crescent Street, Long Island City NY 11106',
#  '1 East 198th Street, Bronx NY 10468',
#  '2830 Morris Avenue, Bronx NY 10468',
#  '16 East 40th Street, New York NY 10016',
#  '260 West 36th Street, New York NY 10018',
#  '20 Plaza Street, Brooklyn NY 11238',
#  '215 East 79th Street, New York NY 10075',
#  '24 Central Park South, New York NY 10019',
#  '100 West 89th Street, New York NY 10024',
#  '1787 Madison Avenue, New York NY 10035',
#  '1831 Madison Avenue, New York NY 10029',
#  '207 East 74th Street, New York NY 10021',
#  '155 East 76th Street, New York NY 10021',
#  '2 Cornelia Street, New York NY 10014',
#  '2754 Claflin Ave, Bronx NY 10468',
#  '600-614 W 181 St, New York NY 10033',
#  '4295 Webster Ave, Bronx NY 10470',
#  '4315 Webster Ave, Bronx NY 10470',
#  '4320 Van Cortlandt Park E, Bronx NY 10470',
#  '3176 Decatur Ave, Bronx NY 10486',
#  '70 Park Terrace East, New York NY 10034',
#  '1000 Pennsylvania Ave, Brooklyn NY 11207',
#  '165-25 Jamaica Ave, Queens NY 11432',
#  '1850 Ocean Pkwy, Brooklyn NY 11223',
#  '40-04 Bowne St, Queens NY 11354',
#  '118-40 Metropolitan Ave, Queens NY 11415',
#  '147-25 Sanford Ave, Flushing NY 11355',
#  '4500 Broadway, New York NY 10040',
#  '64-85 Saunders St, Queens NY 11374',
#  '41-15 45 St, Sunnyside NY 11104',
#  '9602 4 Ave, Brooklyn NY 11209',
#  '41-43 39 Place, Sunnyside NY 11104',
#  '1375 Ocean Ave, Brooklyn NY 11230',
#  '110-21 73 Rd, Queens NY 11375',
#  '745 E 31 St, Brooklyn NY 11210',
#  '8100 Bay Parkway, Brooklyn NY 11214',
#  '540 Ocean Parkway, Brooklyn NY 11218',
#  '62-98 Saunders Street, Queens NY 11374',
#  '142-20 84 Drive, Queens NY 11435',
#  '118-14 83rd Ave, Queens NY 11415',
#  '114-06 Queens Blvd, Queens NY 11375',
#  '107-129 East 126th Street, New York NY 10035',
#  '112-128 East 128th Street, New York NY 10035',
#  '2321 7th Avenue, New York NY 10030',
#  '127 East 107th Street, New York NY 10029',
#  '2146 Lexington Ave, New York NY 10035',
#  '2036 Amsterdam Avenue, New York NY 10032',
#  '135 East 118 Street, New York NY 10035',
#  '1325 5th Avenue, New york NY 10029',
#  '2160-2166 Matthews Ave, Bronx NY 10462',
#  '92-06 63rd Avenue, Queens NY 11374',
#  '76-15 35th Ave, Queens NY 11372',
#  '65-36 Wetherole Street, Queens NY 11374',
#  '37-27 86th Street, Queens NY 11372',
#  '144-63 35th Ave, Queens NY 11354',
#  '40-18 Hampton Street, Queens NY 11373',
#  '37-41 East 18th Street, New York NY 10003',
#  '2488 GRAND CONCOURSE, Bronx NY 10458',
#  '1155 Gerard Ave, Bronx NY 10452',
#  '1347 48th Street, Brooklyn NY 11219',
#  '2320 Kings Hwy, Brooklyn NY 11229',
#  '865 West End Ave, New York NY 10025',
#  '8904 34 AVE, Queens NY 11372',
#  '144-27 35th Avenue, Queens NY 11354',
#  '42-02 Kissena Boulevard, New York NY 11355',
#  '144-31 41st Avenue,, Queens NY 11355',
#  '144-15 41st Avenue, Queens NY 11355',
#  '147-30 38th Avenue, Queens NY 11354',
#  '39-20 Greenpoint Avenue, Queens NY 11104',
#  '36-08 29th Street, Queens NY 11106',
#  '561 Lenox Ave, New York NY 10037',
#  '969 Gates Ave, Brooklyn NY 11221',
#  '116 West 23rd Street, New York NY 10011',
#  '3055 Decatur Ave, Bronx NY 10467',
#  '5520 15th Ave, Brooklyn NY 11219',
#  '1144 Pelham Parkway South, Bronx NY 10461',
#  '2039 Blackrock Ave, Bronx NY 10472',
#  '1477 54 ST, Brooklyn NY 11219',
#  '557 Avenue Z, Brooklyn NY 11223',
#  '8721 Bay Parkway, Brooklyn NY 11214',
#  '383 West Broadway, New York NY 10012',
#  '116 West 29th Street, New York NY 10001',
#  '2710 Morris Ave, Bronx NY 10468',
#  '15 East 32nd Street, new york NY 10016',
#  '2490 Webster Ave, BRONX NY 10458',
#  '2964 Williamsbridge Road, NY NY 10467',
#  '2285 Sedgwick Ave, BRONX NY 10468',
#  '580 Flatbush Ave, Brooklyn NY 11225',
#  '590 Flatbush Ave, Brooklyn NY 11225',
#  '267 Fifth Avenue, New York NY 10016',
#  '1957 Bronxdale Ave., Bronx NY 10462',
#  '8313 Bay Parkway, Brooklyn NY 11214',
#  '580 Broadway, New York NY 10012',
#  '579 Broadway, New York NY 10012',
#  '382 Willoughby Ave, Brooklyn NY 11205',
#  '156 Beach 9th Street UNIT 1, Queens NY 11691',
#  '146 BEACH 9TH ST, 2A, FAR ROCKWY NY 11691',
#  '58 2nd Ave, Brooklyn NY 11221',
#  '425 West 205th Street, New York NY 10034',
#  '35 West 35th Street, New York NY 10001',
#  '260 West 39th Street, New York NY 10018',
#  '259 West 30th St, New York NY 10001',
#  '2263 84th Street, Brooklyn NY 11214',
#  '3133 Brighton 7th Street, Brooklyn NY 11235',
#  '135 West 29th Street, New York NY 10001',
#  '25-26 75th Street, Queens NY 11370',
#  '1476 Utica Ave, Brooklyn NY 11234',
#  '91-30 Van Wyck Expressway, Richmond Hill NY 11418',
#  '653 Hicks St, Brooklyn NY 11231',
#  '30 Dean St, Brooklyn NY 11201',
#  '610 West 142nd Street, New York NY 10031',
#  ...]

# %%
# Example usage:
if __name__ == "__main__":
    address_list = addresses

    successful_df, failed_df = geocode_addresses(address_list)

    # Save results to CSV
    successful_df.to_csv('successful_geocoded_addresses.csv', index=False)
    failed_df.to_csv('failed_geocoded_addresses.csv', index=False)

    print("Geocoding completed.")
    print(f"Successful results saved to 'successful_geocoded_addresses.csv'. Count: {len(successful_df)}")
    print(f"Failed addresses saved to 'failed_geocoded_addresses.csv'. Count: {len(failed_df)}")
    
    print("\nSuccessful Results:")
    print(successful_df)
    
    print("\nFailed Addresses:")
    print(failed_df)
# Out:
# Geocoding completed.
# Successful results saved to 'successful_geocoded_addresses.csv'. Count: 26238
# Failed addresses saved to 'failed_geocoded_addresses.csv'. Count: 4247
#
# Successful Results:
#                                   Search_Address           OSM_ID  \
# 0            58-01 Grand Avenue, Queens NY 11378    way 280166984
# 1      1870 Pelham Parkway South, Bronx NY 10461    way 282171870
# 2           2011 Mott Ave, Far Rockaway NY 11691    way 219959090
# 3        215 East 99th Street, New York NY 10029     way 46694769
# 4              1680 Ocean Ave, Brooklyn NY 11230    way 420339909
# ...                                          ...              ...
# 26233         80 South Street, New York NY 10038  node 4704311989
# 26234        163 Front Street, New York NY 10038    way 278076376
# 26235    15 Lisbon Place, Staten Island NY 10306  node 2545347758
# 26236          450 Zerega Ave, New York NY 10473    way 281882939
# 26237       347-349 Rider Avenue, Bronx NY 10451    way 978670457
#
#                    Name                 Type Last_Updated  Search_Rank  \
# 0                               yes:building      Unknown           30
# 1      The Pelham Grand         yes:building      Unknown           30
# 2           Mott Avenue    secondary:highway      Unknown           26
# 3                                house:place      Unknown           30
# 4                                house:place      Unknown           30
# ...                 ...                  ...          ...          ...
# 26233                            house:place      Unknown           30
# 26234                           yes:building      Unknown           30
# 26235                            house:place      Unknown           30
# 26236                           yes:building      Unknown           30
# 26237      Rider Avenue  residential:highway      Unknown           26
#
#            Address_Rank  Importance Coverage            Latitude  \
# 0              30 (yes)    0.000010    Point         40.72001965
# 1              30 (yes)    0.000092    Point  40.855036150000004
# 2        26 (secondary)    0.053425    Point           40.604978
# 3            30 (house)    0.000010    Point   40.78677690909091
# 4            30 (house)    0.000010    Point  40.621438734693875
# ...                 ...         ...      ...                 ...
# 26233        30 (house)    0.000092    Point          40.7056075
# 26234          30 (yes)    0.000092    Point  40.705844400000004
# 26235        30 (house)    0.000010    Point          40.5818809
# 26236          30 (yes)    0.000092    Point         40.81648105
# 26237  26 (residential)    0.053425    Point          40.8116343
#
#                 Longitude   Height   Place_Id              City  \
# 0      -73.91106784529185      7.0   15386240  City of New York
# 1       -73.8305863965727     18.1   15669731  City of New York
# 2              -73.754419  Unknown   14535501  City of New York
# 3      -73.94689472727272  Unknown  336920808  City of New York
# 4      -73.95569226530611  Unknown  346975725  City of New York
# ...                   ...      ...        ...               ...
# 26233         -74.0043915  Unknown   13584547  City of New York
# 26234  -74.00476374082211     36.1   13382233  City of New York
# 26235         -74.1085329  Unknown   13607632  City of New York
# 26236  -73.84362277671886      9.6   15563943  City of New York
# 26237          -73.928278  Unknown   15385435  City of New York
#
#                      Street Postcode Housenumber  \
# 0              Grand Avenue    11378       58-01
# 1      Pelham Parkway South    10461        1870
# 2               Mott Avenue    11691     Unknown
# 3          East 99th Street    10029         215
# 4              Ocean Avenue    11230        1680
# ...                     ...      ...         ...
# 26233          South Street    10038          80
# 26234          Front Street    10038         163
# 26235          Lisbon Place    10306          15
# 26236         Zerega Avenue    10473         450
# 26237          Rider Avenue    10451     Unknown
#
#                                               Extra_Tags
# 0                                 nycdoitt:bin (4059918)
# 1      website (http://thepelhamgrand.com/), nycdoitt...
# 2                                            oneway (no)
# 3
# 4
# ...                                                  ...
# 26233
# 26234  roof:shape (flat), nycdoitt:bin (1001139), roo...
# 26235
# 26236                             nycdoitt:bin (2021302)
# 26237
#
# [26238 rows x 18 columns]
#
# Failed Addresses:
#                                      Search_Address  \
# 0                  23-25 31 Street, Queens NY 11105
# 1                   90-11 149 str, Jamaica NY 11435
# 2                   148-25 89 Ave, Jamaica NY 11435
# 3                   166-05 89 Ave, Jamaica NY 11432
# 4             57-67 West 175 Street, Bronx NY 10453
# ...                                             ...
# 4242  5, 60, 80 East 93rd Street, Brooklyn NY 11212
# 4243  149-32 132nd Street, Jamaica, Queens NY 11430
# 4244            160 SO. 2ND. ST., BROOKLYN NY 11211
# 4245       1151 Broadway, Ste 2S, New York NY 10001
# 4246          113-25 14 AVE, COLLEGE POINT NY 11356
#
#                                Error
# 0     No data found for this address
# 1     No data found for this address
# 2     No data found for this address
# 3     No data found for this address
# 4     No data found for this address
# ...                              ...
# 4242  No data found for this address
# 4243  No data found for this address
# 4244  No data found for this address
# 4245  No data found for this address
# 4246  No data found for this address
#
# [4247 rows x 2 columns]

# %%
import requests
import time
from typing import List, Dict, Any, Optional
import pandas as pd

def geocode_address(address: str) -> Optional[Dict[str, Any]]:
    """
    Geocode an address using Nominatim and return detailed information.
    
    Args:
    address (str): The address string to geocode.
    
    Returns:
    Optional[Dict[str, Any]]: A dictionary containing detailed metadata if found, None otherwise.
    """
    base_url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": address,
        "format": "json",
        "limit": 1,
        "addressdetails": 1,
        "extratags": 1,
        "namedetails": 1,
        "polygon_geojson": 1
    }
    
    response = requests.get(base_url, params=params, headers={"User-Agent": "YourAppName"})
    data = response.json()
    
    if data:
        result = data[0]
        processed_result = {
            "OSM_ID": f"{result.get('osm_type', 'way')} {result.get('osm_id')}",
            "Name": result.get('name', 'No Name'),
            "Type": f"{result.get('type')}:{result.get('class')}",
            "Last_Updated": result.get('lastupdate', 'Unknown'),
            "Importance": result.get('importance', 0),
            "Coverage": "Polygon" if result.get('geojson', {}).get('type') == 'Polygon' else 'Point',
            "Centre_Point": f"{result.get('lat')}, {result.get('lon')}",
            "Place_Id": result.get('place_id'),
            "Computed_Postcode": result.get('address', {}).get('postcode', 'Unknown'),
            "Address_Tags": ", ".join([f"{k}: {v}" for k, v in result.get('address', {}).items()]),
            "Extra_Tags": ", ".join([f"{k}: {v}" for k, v in result.get('extratags', {}).items()]),
        }
        
        # Process hierarchical address information
        address_parts = []
        for key, value in result.get('address', {}).items():
            osm_type = next((item['osm_type'] for item in data if item.get('type') == key), '')
            osm_id = next((item['osm_id'] for item in data if item.get('type') == key), '')
            address_parts.append({
                "Local_name": value,
                "Type": key,
                "OSM": f"{osm_type} {osm_id}" if osm_type and osm_id else '',
                "Address_rank": len(result.get('address', {})) - list(result.get('address', {}).keys()).index(key)
            })
        processed_result["Address_Hierarchy"] = address_parts
        
        return processed_result
    else:
        return None

# %%
addresses = pd.read_csv(r"C:\Users\Jerem\OneDrive\Desktop\hackathon\addresses.csv")
addresses = addresses['Full Address'].to_list()
addresses = addresses[:2]
addresses
# Out:
# ['58-01 Grand Avenue, Queens NY 11378',
#  '1870 Pelham Parkway South, Bronx NY 10461']

# %%
def geocode_addresses(addresses: List[str]) -> List[Dict[str, Any]]:
    """
    Geocode a list of addresses using Nominatim and return detailed information.
    
    Args:
    addresses (List[str]): A list of address strings to geocode.
    
    Returns:
    List[Dict[str, Any]]: A list of dictionaries containing detailed metadata for each address.
    """
    results = []

    for address in addresses:
        result = geocode_address(address)
        if result:
            results.append(result)
        else:
            results.append({"query": address, "error": "Not found"})
        
        # Be nice to the Nominatim server by waiting between requests
        time.sleep(1)

    return results

# Example usage:
if __name__ == "__main__":
    address_list = [
        "58-01 Grand Avenue, Queens, NY 11378",
        "1600 Amphitheatre Parkway, Mountain View, CA",
        "1 Infinite Loop, Cupertino, CA"
    ]

    geocoded_results = geocode_addresses(address_list)

    # Convert results to DataFrame
    results_df = pd.json_normalize(geocoded_results, 
                                   record_path=['Address_Hierarchy'], 
                                   meta=['OSM_ID', 'Name', 'Type', 'Last_Updated', 'Importance',
                                         'Coverage', 'Centre_Point', 'Place_Id', 'Computed_Postcode',
                                         'Address_Tags', 'Extra_Tags'],
                                   record_prefix='Hierarchy_')

    # Save results to CSV
    results_df.to_csv('detailed_geocoded_addresses.csv', index=False)

    print("Detailed geocoding completed. Results saved to 'detailed_geocoded_addresses.csv'.")
# Out:
# Detailed geocoding completed. Results saved to 'detailed_geocoded_addresses.csv'.

# %%
for address in addresses:
    lat, lon = geocode_address(address)
    if lat and lon:
        results.append([address, lat, lon])
    else:
        results.append([address, "Not found", "Not found"])
    
    # Be nice to the Nominatim server by waiting between requests
    time.sleep(1)

# Save results to CSV
with open('geocoded_addresses.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Address', 'Latitude', 'Longitude'])
    writer.writerows(results)

print("Geocoding completed. Results saved to 'geocoded_addresses.csv'.")
